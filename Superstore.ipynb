# %% [markdown]
# # The Sparks Foundation

# %% [markdown]
# # Task 3 Exploratory Data Analysis

# %% [markdown]
# # Importing the Libraries

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing the Data

# %%
data=pd.read_csv('SampleSuperstore.csv')
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # Checking for null data if any

# %%
(data.isnull()).sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# # Describing Data

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
sns.pairplot(data,hue="Ship Mode")

# %%
sns.countplot(data=data,x="Ship Mode")

# %% [markdown]
# ## Conclusion : Standard class is the most preferred Ship Mode

# %%
plt.figure(figsize=[10,10])
plt.xticks(rotation=90)
sns.countplot(data=data,x="State")

# %% [markdown]
# ## Conclusion : California is the state with highest number of consumers

# %%
data['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
plt.pie(data.Category.value_counts(),labels=data.Category.value_counts().index,textprops={'fontsize': 15}, startangle=90,
        autopct='%1.0f%%',colors=['#ff7675', '#ffeaa7', '#55efc4'],pctdistance=0.8,
        labeldistance=1.18)
centre_circle = plt.Circle((0, 0), radius=0.6, fc='white')
plt.gca().add_artist(centre_circle)
plt.show()

# %% [markdown]
# ## Conclusion : Office Supplies are Sold approx 60%

# %%
data['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=[12,12])
plt.pie(data['Sub-Category'].value_counts(),labels=data['Sub-Category'].value_counts().index,textprops={'fontsize': 14}, startangle=90,
        autopct="%1.0f%%",
        pctdistance=0.8,
        labeldistance=1.18)
centre_circle = plt.Circle((0, 0), radius=0.6, fc='white')
plt.gca().add_artist(centre_circle)
plt.show()

# %%
data['Quantity'].value_counts()
# Out:
# 3     2409
# 2     2402
# 5     1230
# 4     1191
# 1      899
# 7      606
# 6      572
# 9      258
# 8      257
# 10      57
# 11      34
# 14      29
# 13      27
# 12      23
# Name: Quantity, dtype: int64

# %%
sns.countplot(data.Quantity)

# %% [markdown]
# ## Conclusion : Mostly 2-3 items are bought by consumers

# %%
sns.pairplot(data,hue="Discount")

# %%
data.Discount.value_counts()
# Out:
# 0.00    4798
# 0.20    3657
# 0.70     418
# 0.80     300
# 0.30     227
# 0.40     206
# 0.60     138
# 0.10      94
# 0.50      66
# 0.15      52
# 0.32      27
# 0.45      11
# Name: Discount, dtype: int64

# %%
plt.figure(figsize=[10,10])
plt.pie(data['Discount'].value_counts(),textprops={'fontsize': 14}, startangle=90,
        pctdistance=0.8,
        labeldistance=1.18)
centre_circle = plt.Circle((0, 0), radius=0.6, fc='white')
plt.legend(labels=data['Discount'].value_counts().index)
plt.gca().add_artist(centre_circle)
plt.show()
